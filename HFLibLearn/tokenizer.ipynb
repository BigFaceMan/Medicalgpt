# %%
from transformers import AutoTokenizer

tok = AutoTokenizer.from_pretrained("/lfs1/users/spsong/Code/MedicalGPT/output/qwen3B-instruct-sft-merge", trust_remote_code=True)
print("<tool_call>" in tok.all_special_tokens)
print(tok.convert_tokens_to_ids("<tool_call>"))
print(tok.all_special_tokens[:20])
# Out:
# False
# 151657
# ['<|im_end|>', '<|endoftext|>', '<|im_start|>', '<|object_ref_start|>', '<|object_ref_end|>', '<|box_start|>', '<|box_end|>', '<|quad_start|>', '<|quad_end|>', '<|vision_start|>', '<|vision_end|>', '<|vision_pad|>', '<|image_pad|>', '<|video_pad|>']

# %%
len(tok.all_special_tokens)
tok.all_special_tokens
# Out:
# 14

# %%
from transformers import AutoConfig, AutoModelForSequenceClassification


model_name_or_path = "/lfs1/users/spsong/Code/MedicalGPT/output/qwen0.5B-instruct-merge"

config = AutoConfig.from_pretrained(
    model_name_or_path,
    num_labels=1
)
# Out:
# loading configuration file /lfs1/users/spsong/Code/MedicalGPT/output/qwen0.5B-instruct-merge/config.json
# Model config Qwen2Config {
#   "architectures": [
#     "Qwen2ForCausalLM"
#   ],
#   "attention_dropout": 0.0,
#   "bos_token_id": 151643,
#   "dtype": "bfloat16",
#   "eos_token_id": 151645,
#   "hidden_act": "silu",
#   "hidden_size": 896,
#   "id2label": {
#     "0": "LABEL_0"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 4864,
#   "label2id": {
#     "LABEL_0": 0
#   },
#   "layer_types": [
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
# ...

# %%
print(config.num_labels)
print(type(config))
# Out:
# 1
# <class 'transformers.models.qwen2.configuration_qwen2.Qwen2Config'>

# %%
from transformers.models.qwen2.configuration_qwen2 import Qwen2Config

Qwen2Config

# %%
model = AutoModelForSequenceClassification.from_pretrained(
    model_name_or_path,
    config=config,
)
# Out:
# loading weights file /lfs1/users/spsong/Code/MedicalGPT/output/qwen0.5B-instruct-merge/model.safetensors
# Will use dtype=torch.bfloat16 as defined in model's config object
# Loading weights: 100%|██████████| 290/290 [00:00<00:00, 4322.29it/s]
# Qwen2ForSequenceClassification LOAD REPORT from: /lfs1/users/spsong/Code/MedicalGPT/output/qwen0.5B-instruct-merge
# Key          | Status  |
# -------------+---------+-
# score.weight | MISSING |
#
# Notes:
# - MISSING	:those params were newly initialized because missing from the checkpoint. Consider training on your downstream task.

# %%
print(model)
# Out:
# Qwen2ForSequenceClassification(
#   (model): Qwen2Model(
#     (embed_tokens): Embedding(151936, 896)
#     (layers): ModuleList(
#       (0-23): 24 x Qwen2DecoderLayer(
#         (self_attn): Qwen2Attention(
#           (q_proj): Linear(in_features=896, out_features=896, bias=True)
#           (k_proj): Linear(in_features=896, out_features=128, bias=True)
#           (v_proj): Linear(in_features=896, out_features=128, bias=True)
#           (o_proj): Linear(in_features=896, out_features=896, bias=False)
#         )
#         (mlp): Qwen2MLP(
#           (gate_proj): Linear(in_features=896, out_features=4864, bias=False)
#           (up_proj): Linear(in_features=896, out_features=4864, bias=False)
#           (down_proj): Linear(in_features=4864, out_features=896, bias=False)
#           (act_fn): SiLUActivation()
#         )
#         (input_layernorm): Qwen2RMSNorm((896,), eps=1e-06)
#         (post_attention_layernorm): Qwen2RMSNorm((896,), eps=1e-06)
#       )
#     )
# ...

# %%
from transformers import AutoModelForCausalLM

model_qwen2 = AutoModelForCausalLM.from_pretrained(
    model_name_or_path
)
print(model_qwen2)
# Out:
# loading configuration file /lfs1/users/spsong/Code/MedicalGPT/output/qwen0.5B-instruct-merge/config.json
# Model config Qwen2Config {
#   "architectures": [
#     "Qwen2ForCausalLM"
#   ],
#   "attention_dropout": 0.0,
#   "bos_token_id": 151643,
#   "dtype": "bfloat16",
#   "eos_token_id": 151645,
#   "hidden_act": "silu",
#   "hidden_size": 896,
#   "initializer_range": 0.02,
#   "intermediate_size": 4864,
#   "layer_types": [
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
# ...

# %%
rm_model_path = "/lfs1/users/spsong/Code/MedicalGPT/output/qwen0.5B-instruct-rm-merge"
model_rm = AutoModelForSequenceClassification.from_pretrained(
    rm_model_path,
)
# Out:
# loading configuration file /lfs1/users/spsong/Code/MedicalGPT/output/qwen0.5B-instruct-rm-merge/config.json
# Model config Qwen2Config {
#   "architectures": [
#     "Qwen2ForSequenceClassification"
#   ],
#   "attention_dropout": 0.0,
#   "bos_token_id": 151643,
#   "dtype": "float32",
#   "eos_token_id": 151645,
#   "hidden_act": "silu",
#   "hidden_size": 896,
#   "id2label": {
#     "0": "LABEL_0"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 4864,
#   "label2id": {
#     "LABEL_0": 0
#   },
#   "layer_types": [
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
#     "full_attention",
# ...

# %%
medical_sft_path = "/lfs1/users/spsong/Code/MedicalGPT/data/finetune/medical_sft_1K_format.jsonl"
share_gpt_path = "/lfs1/users/spsong/Code/MedicalGPT/data/finetune/sharegpt_zh_1K_format.jsonl"
import json
with open(medical_sft_path, "r") as f:
    medical_sft_data = [json.loads(line) for line in f]

for cons in medical_sft_data:
    if len(cons["conversations"]) > 2:
        print("medical got muti turn")

with open(share_gpt_path, "r") as f:
    share_gpt_data = [json.loads(line) for line in f]

for cons in share_gpt_data:
    if len(cons["conversations"]) > 2:
        print("share gpt got muti turn")
# Out:
# share gpt got muti turn
# share gpt got muti turn
# share gpt got muti turn
# share gpt got muti turn
# share gpt got muti turn
# share gpt got muti turn
# share gpt got muti turn
# share gpt got muti turn
# share gpt got muti turn
# share gpt got muti turn
# share gpt got muti turn
# share gpt got muti turn
# share gpt got muti turn
# share gpt got muti turn
# share gpt got muti turn
# share gpt got muti turn
# share gpt got muti turn
# share gpt got muti turn
# share gpt got muti turn
# share gpt got muti turn
# share gpt got muti turn
# share gpt got muti turn
# share gpt got muti turn
# share gpt got muti turn
# share gpt got muti turn
# share gpt got muti turn
# share gpt got muti turn
# share gpt got muti turn
# share gpt got muti turn
# share gpt got muti turn
# share gpt got muti turn
# share gpt got muti turn
# share gpt got muti turn
# share gpt got muti turn
# share gpt got muti turn
# share gpt got muti turn
# share gpt got muti turn
# share gpt got muti turn
# ...
